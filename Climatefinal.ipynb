# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
climatechange=pd.read_csv('GlobalLandTemperaturesByState.csv')

# %%
climatechange.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
climatechange.isnull().sum()
# Out:
# dt                                   0
# AverageTemperature               25648
# AverageTemperatureUncertainty    25648
# State                                0
# Country                              0
# dtype: int64

# %%
climatechange['year'] = pd.DatetimeIndex(climatechange['dt']).year
climatechange['month'] = pd.DatetimeIndex(climatechange['dt']).month
climatechange['dt']=pd.to_datetime(climatechange.dt)
climatechange=climatechange[climatechange['year']>1980]
climatechange.head()
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty State  \
# 1508 1981-01-01              26.076                          0.237  Acre
# 1509 1981-02-01              25.635                          0.383  Acre
# 1510 1981-03-01              26.244                          0.348  Acre
# 1511 1981-04-01              26.038                          0.211  Acre
# 1512 1981-05-01              26.463                          0.353  Acre
#
#      Country  year  month
# 1508  Brazil  1981      1
# 1509  Brazil  1981      2
# 1510  Brazil  1981      3
# 1511  Brazil  1981      4
# 1512  Brazil  1981      5

# %%
des=climatechange.describe()
des.year=des.year.astype(int)
des.month=des.month.astype(int)

# %%
des
# Out:
#        AverageTemperature  AverageTemperatureUncertainty   year  month
# count        94532.000000                   94532.000000  94713  94713
# mean            10.351600                       0.299140   1996      6
# std             13.701776                       0.163417      9      3
# min            -43.002000                       0.044000   1981      1
# 25%              1.139750                       0.204000   1989      3
# 50%             12.665000                       0.263000   1997      6
# 75%             21.358000                       0.346000   2005      9
# max             36.339000                       5.435000   2013     12

# %%
climatechange.head()
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty State  \
# 1508 1981-01-01              26.076                          0.237  Acre
# 1509 1981-02-01              25.635                          0.383  Acre
# 1510 1981-03-01              26.244                          0.348  Acre
# 1511 1981-04-01              26.038                          0.211  Acre
# 1512 1981-05-01              26.463                          0.353  Acre
#
#      Country  year  month
# 1508  Brazil  1981      1
# 1509  Brazil  1981      2
# 1510  Brazil  1981      3
# 1511  Brazil  1981      4
# 1512  Brazil  1981      5

# %%
climatechange.isnull().sum()
# Out:
# dt                                 0
# AverageTemperature               181
# AverageTemperatureUncertainty    181
# State                              0
# Country                            0
# year                               0
# month                              0
# dtype: int64

# %%
pip install pycountry-convert
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

# %%
import pycountry_convert as pc

# %%
def country_to_continent(country_name):
    country_alpha2 = pc.country_name_to_country_alpha2(country_name)
    country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
    country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    return country_continent_name
countries = list(climatechange['Country'])

[country_to_continent(Country)for Country in countries]
# Out:
# ['South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
#  'South America',
# ...

# %%
climatechange['continent'] = climatechange['Country'].apply(country_to_continent)

# %%
climatechange.to_csv('Global_Land_Temp.csv', sep=',')
