# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# This magic line will allow you to generate plots
# within the Jupyter notebook.
# %matplotlib inline

#this adds some extra styling to the graphs we will make
sns.set_style("whitegrid")

# %%
df=pd.read_csv("GlobalLandTemperatures_GlobalTemperatures.csv")

# %%
df.shape
# Out:
# (3192, 9)

# %%
df.columns
# Out:
# Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty'],
#       dtype='object')

# %%
df['dt'] = pd.to_datetime(df['dt'])

# %%
df['year'] = df['dt'].dt.year
df['month'] = df['dt'].dt.month
df['day'] = df['dt'].dt.day

# %%
df.columns
# Out:
# Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty', 'year', 'month', 'day'],
#       dtype='object')

# %%
df['year'].head(10)
# Out:
# 0    1750
# 1    1750
# 2    1750
# 3    1750
# 4    1750
# 5    1750
# 6    1750
# 7    1750
# 8    1750
# 9    1750
# Name: year, dtype: int64

# %%
df.drop(df[df['year']<1901].index, inplace=True)

# %%
df.shape
# Out:
# (1380, 12)

# %%
df['dt'].isna().sum()
# Out:
# 0

# %%
avg_yearly=df[['LandAverageTemperature','year']]\
.groupby(['year'],as_index=False).mean()

# %%
avg_yearly.columns=['year','AverageYearlyTemp']

# %%
avg_yearly
# Out:
#      year  AverageYearlyTemp
# 0    1901           8.541917
# 1    1902           8.304417
# 2    1903           8.220167
# 3    1904           8.090917
# 4    1905           8.225167
# ..    ...                ...
# 110  2011           9.516000
# 111  2012           9.507333
# 112  2013           9.606500
# 113  2014           9.570667
# 114  2015           9.831000
#
# [115 rows x 2 columns]

# %%
df=pd.merge(df,avg_yearly,on='year')

# %%
df
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0    1901-01-01                   2.191                              0.291
# 1    1901-01-02                   3.092                              0.418
# 2    1901-01-03                   5.671                              0.251
# 3    1901-01-04                   8.522                              0.326
# 4    1901-01-05                  11.178                              0.339
# ...         ...                     ...                                ...
# 1375 2015-01-08                  14.755                              0.072
# 1376 2015-01-09                  12.999                              0.079
# 1377 2015-01-10                  10.801                              0.102
# 1378 2015-01-11                   7.433                              0.119
# 1379 2015-01-12                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                  7.996                          0.604              -3.491
# 1                  9.038                          0.371              -2.678
# 2                 11.476                          0.370              -0.644
# 3                 14.733                          0.368               2.264
# 4                 17.315                          0.397               4.855
# ...                  ...                            ...                 ...
# 1375              20.699                          0.110               9.005
# 1376              18.845                          0.088               7.199
# 1377              16.450                          0.059               5.232
# 1378              12.892                          0.093               2.157
# 1379              10.725                          0.154               0.287
#
#       LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                             0.490                          13.290
# 1                             0.539                          13.660
# 2                             0.395                          14.383
# 3                             0.376                          15.220
# 4                             0.390                          15.936
# ...                             ...                             ...
# 1375                          0.170                          17.589
# 1376                          0.229                          17.049
# 1377                          0.115                          16.290
# 1378                          0.106                          15.252
# 1379                          0.099                          14.774
#
#       LandAndOceanAverageTemperatureUncertainty  year  month  day  \
# 0                                         0.141  1901      1    1
# 1                                         0.163  1901      1    2
# 2                                         0.138  1901      1    3
# 3                                         0.151  1901      1    4
# 4                                         0.154  1901      1    5
# ...                                         ...   ...    ...  ...
# 1375                                      0.057  2015      1    8
# 1376                                      0.058  2015      1    9
# 1377                                      0.062  2015      1   10
# 1378                                      0.063  2015      1   11
# 1379                                      0.062  2015      1   12
#
#       AverageYearlyTemp
# 0              8.541917
# 1              8.541917
# 2              8.541917
# 3              8.541917
# 4              8.541917
# ...                 ...
# 1375           9.831000
# 1376           9.831000
# 1377           9.831000
# 1378           9.831000
# 1379           9.831000
#
# [1380 rows x 13 columns]

# %%
df.to_csv('Global_Temp.csv', sep=',')

# %%
avg_yearly.to_csv('GlobalYearlyLand_Temp.csv', sep=',')

# %%
df[['year','LandAndOceanAverageTemperature','LandAverageTemperature']]
# Out:
#       year  LandAndOceanAverageTemperature  LandAverageTemperature
# 0     1901                          13.290                   2.191
# 1     1901                          13.660                   3.092
# 2     1901                          14.383                   5.671
# 3     1901                          15.220                   8.522
# 4     1901                          15.936                  11.178
# ...    ...                             ...                     ...
# 1375  2015                          17.589                  14.755
# 1376  2015                          17.049                  12.999
# 1377  2015                          16.290                  10.801
# 1378  2015                          15.252                   7.433
# 1379  2015                          14.774                   5.518
#
# [1380 rows x 3 columns]

# %%
avg_yearly_landOcean=df[['LandAndOceanAverageTemperature','year']]\
.groupby(['year'],as_index=False).mean()

# %%
avg_yearly_landOcean.columns=['year','AverageYearlyLandOceanTemp']

# %%
avg_yearly_landOcean
# Out:
#      year  AverageYearlyLandOceanTemp
# 0    1901                   15.073333
# 1    1902                   14.958333
# 2    1903                   14.836583
# 3    1904                   14.810417
# 4    1905                   14.954667
# ..    ...                         ...
# 110  2011                   15.769500
# 111  2012                   15.802333
# 112  2013                   15.854417
# 113  2014                   15.913000
# 114  2015                   16.058583
#
# [115 rows x 2 columns]

# %%
final=pd.merge(avg_yearly,avg_yearly_landOcean,on='year')

# %%
final
# Out:
#      year  AverageYearlyTemp  AverageYearlyLandOceanTemp
# 0    1901           8.541917                   15.073333
# 1    1902           8.304417                   14.958333
# 2    1903           8.220167                   14.836583
# 3    1904           8.090917                   14.810417
# 4    1905           8.225167                   14.954667
# ..    ...                ...                         ...
# 110  2011           9.516000                   15.769500
# 111  2012           9.507333                   15.802333
# 112  2013           9.606500                   15.854417
# 113  2014           9.570667                   15.913000
# 114  2015           9.831000                   16.058583
#
# [115 rows x 3 columns]

# %%
final.to_csv('Global_Land_LandOcean_Temp.csv', sep=',')
